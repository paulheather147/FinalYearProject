# %% [markdown]
# <a href="https://colab.research.google.com/github/paulheather147/FinalYearProject/blob/main/FinalModelSyntheticDataAndCBAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Final Model with Synthetic Data and CBAM")
# Out:
# Final Model with Synthetic Data and CBAM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q datasets

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16, EfficientNetB2
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_preprocess
from datasets import load_dataset, Dataset

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import numpy as np

from PIL import Image
import os
import matplotlib.pyplot as plt
import cv2
import torch
import glob
import math

from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate, Conv2D, Add, Activation, Lambda
from tensorflow.keras import backend as K

# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA L4 (UUID: GPU-8ece455b-8358-07c3-046b-59e60ee1bb29)

# %%
dataset = load_dataset("Falah/Alzheimer_MRI")
print(dataset)
print(dataset["train"].features)

# %%
train_val_split = dataset["train"].train_test_split(test_size=0.2, seed=42)
train = train_val_split["train"]
val = train_val_split["test"]
test = dataset["test"]

synth_dir = "/content/drive/MyDrive/Moderate_Demented_Synthetic"
synth_files = sorted(glob.glob(f"{synth_dir}/seed*.png"))
print("Found", len(synth_files), "synthetic images.")

def load_synth_example(path):
    img = Image.open(path).convert("L")
    img = np.array(img)
    return {"image": img, "label": 1}

synth_data = [load_synth_example(p) for p in synth_files]
synth_dataset = Dataset.from_list(synth_data)
print(synth_dataset)

def ensure_channel_dim(images):
    current_rank = tf.rank(images)

    def add_channel():
        return tf.expand_dims(images, axis=-1)

    def keep_same():
        return images

    return tf.cond(tf.equal(current_rank, 2), add_channel, keep_same)


def ensure_rgb_channels(images):
    current_channels = tf.shape(images)[-1]

    def to_rgb():
        return tf.image.grayscale_to_rgb(images)

    def drop_alpha():
        return images[..., :3]

    def keep_same():
        return images

    images = tf.cond(tf.equal(current_channels, 1), to_rgb, keep_same)

    new_channels = tf.shape(images)[-1]

    def keep_images_rgb():
        return images

    images = tf.cond(tf.equal(new_channels, 4), drop_alpha, keep_images_rgb)
    return images

def to_tensorflow_dataset(dataset_split, image_size, preprocess_fn, shuffle=False):
        dataset_tf = dataset_split.to_tf_dataset(
        columns=["image", "label"],
        shuffle=shuffle,
        num_workers=0,
    )
        def preprocess_input(example_dict):
            images = tf.cast(example_dict["image"], tf.float32)
            images = ensure_channel_dim(images)
            images = ensure_rgb_channels(images)
            images.set_shape([None, None, 3])
            images = tf.image.resize(images, (image_size, image_size))
            images = preprocess_fn(images)

            labels = tf.cast(example_dict["label"], tf.int32)
            labels = tf.one_hot(labels, depth=4)
            return images, labels

        dataset_tf = dataset_tf.map(preprocess_input,
                                    num_parallel_calls=tf.data.AUTOTUNE)
        dataset_tf = dataset_tf.batch(50)
        return dataset_tf.prefetch(tf.data.AUTOTUNE)

vgg_clean_train = to_tensorflow_dataset(train, 224, vgg_preprocess, shuffle=True)
eff_clean_train = to_tensorflow_dataset(train, 260, eff_preprocess, shuffle=True)

vgg_synth_train = to_tensorflow_dataset(synth_dataset, 224, vgg_preprocess, shuffle=True)
eff_synth_train = to_tensorflow_dataset(synth_dataset, 260, eff_preprocess, shuffle=True)

full_vgg_synth_train = vgg_synth_train.concatenate(vgg_clean_train)
full_eff_synth_train = eff_synth_train.concatenate(eff_clean_train)

vgg_train_dataset = to_tensorflow_dataset(train, 224, vgg_preprocess, shuffle=True)
vgg_val_dataset = to_tensorflow_dataset(val, 224, vgg_preprocess, shuffle=False)
vgg_test_dataset = to_tensorflow_dataset(test, 224, vgg_preprocess, shuffle=False)

eff_train_dataset = to_tensorflow_dataset(train, 260, eff_preprocess, shuffle=True)
eff_val_dataset = to_tensorflow_dataset(val, 260, eff_preprocess, shuffle=False)
eff_test_dataset = to_tensorflow_dataset(test, 260, eff_preprocess, shuffle=False)

vgg_full_train_dataset = vgg_train_dataset
eff_full_train_dataset = eff_train_dataset
# Out:
# Found 50 synthetic images.
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 50
# })

# %%
def channel_attention(x, ratio=8):
    ch = K.int_shape(x)[-1]
    hidden = max(ch // ratio, 1)

    shared_1 = layers.Dense(hidden, activation="relu", kernel_initializer="he_normal", use_bias=True)
    shared_2 = layers.Dense(ch, kernel_initializer="he_normal", use_bias=True)

    avg = layers.GlobalAveragePooling2D(keepdims=True)(x)
    mx  = layers.GlobalMaxPooling2D(keepdims=True)(x)

    attn = layers.Add()([shared_2(shared_1(avg)), shared_2(shared_1(mx))])
    attn = layers.Activation("sigmoid")(attn)
    return layers.Multiply()([x, attn])

def spatial_attention(x, kernel_size=7):
    avg = tf.keras.ops.mean(x, axis=-1, keepdims=True)
    mx  = tf.keras.ops.max(x, axis=-1, keepdims=True)
    concat = layers.Concatenate(axis=-1)([avg, mx])
    attn = layers.Conv2D(
        1, kernel_size, padding="same", activation="sigmoid",
        kernel_initializer="he_normal", use_bias=False
    )(concat)
    return layers.Multiply()([x, attn])

def cbam_block(x, ratio=8):
    y = channel_attention(x, ratio)
    y = spatial_attention(y)
    return layers.Add()([x, y])

# %%
vgg_base = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3),
)

vgg_base.trainable = False

vgg_inputs = tf.keras.Input(shape=(224, 224, 3))
x = vgg_base(vgg_inputs, training=False)
x = cbam_block(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
vgg_outputs = layers.Dense(4, activation="softmax")(x)

vgg_model = tf.keras.Model(vgg_inputs, vgg_outputs)

vgg_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

vgg_model.summary()

# use add_1 for gradcam
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1, 1, 512) │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 1, 1, 512) │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 64)  │     32,832 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 512) │     33,280 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 512) │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 1, 512) │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 7, 7, 512) │          0 │ vgg16[0][0],      │
# │                     │                   │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean (Mean)         │ (None, 7, 7, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max (Max)           │ (None, 7, 7, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 7, 7, 2)   │          0 │ mean[0][0],       │
# │ (Concatenate)       │                   │            │ max[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 7, 7, 1)   │         98 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 7, 7, 512) │          0 │ multiply[0][0],   │
# │ (Multiply)          │                   │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 7, 7, 512) │          0 │ vgg16[0][0],      │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ add_1[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      1,028 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,913,254 (56.89 MB)
#  Trainable params: 198,566 (775.65 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
VGG_EPOCHS = 50

class_weight = {
    0: 1.25,
    1: 2.0,
    2: 1.0,
    3: 1.0,
}

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=5,
    min_lr=1e-6
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

vgg_history_phase0 = vgg_model.fit(
    vgg_clean_train,
    validation_data=vgg_val_dataset,
    epochs=1,
    class_weight=class_weight,
)

vgg_history_phase1 = vgg_model.fit(
    full_vgg_synth_train,
    validation_data=vgg_val_dataset,
    epochs=10,
    class_weight=class_weight,
    callbacks=[reduce_lr, early_stop]
)

vgg_history_phase2 = vgg_model.fit(
    vgg_full_train_dataset,
    validation_data = vgg_val_dataset,
    epochs = VGG_EPOCHS,
    class_weight = class_weight,
    callbacks = [reduce_lr, early_stop]
)

print("\n=== PHASE 2: Fine-tuning top layers ===")
vgg_base.trainable = True
for layer in vgg_base.layers[:-8]:
    layer.trainable = False

print(f"Trainable layers: {sum([l.trainable for l in vgg_base.layers])} / {len(vgg_base.layers)}")

vgg_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

vgg_history_phase3 = vgg_model.fit(
    vgg_full_train_dataset,
    validation_data = vgg_val_dataset,
    epochs = VGG_EPOCHS,
    class_weight = class_weight,
    callbacks = [reduce_lr, early_stop]
)

print("\n=== FINAL VGG16 EVALUATION ===")
vgg_test_loss, vgg_test_acc = vgg_model.evaluate(vgg_test_dataset, verbose=0)
print(f"VGG16 final test accuracy: {vgg_test_acc:.4f}")
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 67s 539ms/step - accuracy: 0.4263 - loss: 4.5296 - val_accuracy: 0.5498 - val_loss: 0.9856
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.4745 - loss: 1.6604 - val_accuracy: 0.5898 - val_loss: 0.9225 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.5455 - loss: 1.0835 - val_accuracy: 0.5928 - val_loss: 0.8775 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.6020 - loss: 0.9280 - val_accuracy: 0.6055 - val_loss: 0.8755 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6211 - loss: 0.8873 - val_accuracy: 0.6201 - val_loss: 0.8341 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6353 - loss: 0.8461 - val_accuracy: 0.6133 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 198ms/step - accuracy: 0.6457 - loss: 0.8203 - val_accuracy: 0.6172 - val_loss: 0.7956 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6568 - loss: 0.8035 - val_accuracy: 0.6631 - val_loss: 0.7510 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6919 - loss: 0.7392 - val_accuracy: 0.6592 - val_loss: 0.7685 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6832 - loss: 0.7408 - val_accuracy: 0.6689 - val_loss: 0.7234 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.6853 - loss: 0.7311 - val_accuracy: 0.6934 - val_loss: 0.7071 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Epoch 1/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 16s 200ms/step - accuracy: 0.6866 - loss: 0.7385 - val_accuracy: 0.6689 - val_loss: 0.7059 - learning_rate: 0.0010
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 16s 199ms/step - accuracy: 0.
# Epoch 9/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.8564 - loss: 0.4071 - val_accuracy: 0.8525 - val_loss: 0.3804 - learning_rate: 1.0000e-04
# Epoch 10/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.8700 - loss: 0.3648 - val_accuracy: 0.8213 - val_loss: 0.4426 - learning_rate: 1.0000e-04
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9178 - loss: 0.2377 - val_accuracy: 0.8584 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9421 - loss: 0.1767 - val_accuracy: 0.8965 - val_loss: 0.3015 - learning_rate: 1.0000e-04
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9748 - loss: 0.0927 - val_accuracy: 0.8643 - val_loss: 0.4693 - learning_rate: 1.0000e-04
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9779 - loss: 0.0755 - val_accuracy: 0.9355 - val_loss: 0.2038 - learning_rate: 1.0000e-04
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9822 - loss: 0.0469 - val_accuracy: 0.9375 - val_loss: 0.2003 - learning_rate: 1.0000e-04
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9912 - loss: 0.0331 - val_accuracy: 0.9033 - val_loss: 0.3951 - learning_rate: 1.0000e-04
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9739 - loss: 0.0739 - val_accuracy: 0.8750 - val_loss: 0.4043 - learning_rate: 1.0000e-04
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9771 - loss: 0.0641 - val_accuracy: 0.9209 - val_loss: 0.2403 - learning_rate: 1.0000e-04
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9896 - loss: 0.0331 - val_accuracy: 0.9580 - val_loss: 0.1393 - learning_rate: 1.0000e-04
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9609 - val_loss: 0.1665 - learning_rate: 1.0000e-04
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9943 - loss: 0.0223 - val_accuracy: 0.8564 - val_loss: 0.4908 - learning_rate: 1.0000e-04
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9487 - loss: 0.1362 - val_accuracy: 0.9189 - val_loss: 0.2305 - learning_rate: 1.0000e-04
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9940 - loss: 0.0273 - val_accuracy: 0.9521 - val_loss: 0.1789 - learning_rate: 1.0000e-04
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9880 - loss: 0.0349 - val_accuracy: 0.9326 - val_loss: 0.2032 - learning_rate: 1.0000e-04
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9921 - loss: 0.0264 - val_accuracy: 0.9678 - val_loss: 0.1338 - learning_rate: 1.0000e-04
# Epoch 26/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9658 - val_loss: 0.1338 - learning_rate: 1.0000e-04
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9668 - val_loss: 0.1502 - learning_rate: 1.0000e-04
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 262ms/step - accuracy: 1.0000 - loss: 8.0838e-04 - val_accuracy: 0.9658 - val_loss: 0.1601 - learning_rate: 1.0000e-04
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 264ms/step - accuracy: 0.9974 - loss: 0.0090 - val_accuracy: 0.9424 - val_loss: 0.1890 - learning_rate: 1.0000e-04
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9934 - loss: 0.0267 - val_accuracy: 0.7373 - val_loss: 0.9221 - learning_rate: 1.0000e-04
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.9750 - loss: 0.0731 - val_accuracy: 0.9551 - val_loss: 0.1173 - learning_rate: 1.0000e-05
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9561 - val_loss: 0.1160 - learning_rate: 1.0000e-05
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9580 - val_loss: 0.1183 - learning_rate: 1.0000e-05
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9600 - val_loss: 0.1202 - learning_rate: 1.0000e-05
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 9.8616e-04 - val_accuracy: 0.9590 - val_loss: 0.1200 - learning_rate: 1.0000e-05
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9600 - val_loss: 0.1199 - learning_rate: 1.0000e-06
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 1.0000 - loss: 9.9934e-04 - val_accuracy: 0.9590 - val_loss: 0.1201 - learning_rate: 1.0000e-06
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 25.
#
# === FINAL VGG16 EVALUATION ===
# VGG16 final test accuracy: 0.9609

# %%
save_dir = "/content/drive/MyDrive/alz_models"
os.makedirs(save_dir, exist_ok=True)

vgg_path = os.path.join(save_dir, "SYNTHandCBAM_VGG.keras")
vgg_model.save(vgg_path)

print("Saved VGG model to:", vgg_path)
# Out:
# Saved VGG model to: /content/drive/MyDrive/alz_models/SYNTHandCBAM_VGG.keras

# %%
y_true = []
y_pred = []

for images, labels in vgg_test_dataset:
    preds = vgg_model.predict(images)

    true_classes = np.argmax(labels.numpy(), axis=1)

    y_true.extend(true_classes)
    y_pred.extend(np.argmax(preds, axis=1))

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[157   0   0  15]
#  [  0  12   0   3]
#  [  2   0 610  22]
#  [  2   0   6 451]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94       172
#            1       1.00      0.80      0.89        15
#            2       0.99      0.96      0.98       634
#            3       0.92      0.98      0.95       459
#
#     accuracy                           0.96      1280
#    macro avg       0.97      0.91      0.94      1280
# weighted avg       0.96      0.96      0.96      1280

# %%
eff_base = EfficientNetB2(
    weights="imagenet",
    include_top=False,
    input_shape=(260, 260, 3),
)
eff_base.trainable = False

eff_inputs = tf.keras.Input(shape=(260, 260, 3))
y = eff_base(eff_inputs, training=False)
y = layers.GlobalAveragePooling2D()(y)
y = layers.Dense(256, activation="relu")(y)
y = layers.Dropout(0.5)(y)
eff_outputs = layers.Dense(4, activation="softmax")(y)

eff_model = tf.keras.Model(eff_inputs, eff_outputs)

eff_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

eff_model.summary()

# use top_conv for gradcam
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 260, 260, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb2 (Functional)     │ (None, 9, 9, 1408)     │     7,768,569 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1408)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       360,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,130,301 (31.01 MB)
#  Trainable params: 361,732 (1.38 MB)
#  Non-trainable params: 7,768,569 (29.63 MB)

# %%
EFF_EPOCHS = 50

class_weight = {
    0: 1.25,
    1: 2.0,
    2: 1.0,
    3: 1.0,
}

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=5,
    min_lr=1e-6
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

eff_history_phase0 = eff_model.fit(
    eff_clean_train,
    validation_data=eff_val_dataset,
    epochs=1,
    class_weight=class_weight,
)

eff_history_phase1 = eff_model.fit(
    full_eff_synth_train,
    validation_data=eff_val_dataset,
    epochs=10,
    class_weight=class_weight,
    callbacks=[reduce_lr, early_stop]
)

eff_history_phase2 = eff_model.fit(
    eff_full_train_dataset,
    validation_data=eff_val_dataset,
    epochs=EFF_EPOCHS,
    class_weight=class_weight,
    callbacks = [reduce_lr, early_stop]
)


print("\n=== PHASE 2: Fine-tuning top layers ===")
eff_base.trainable = True
for layer in eff_base.layers[:-8]:
    layer.trainable = False

print(f"Trainable layers: {sum([l.trainable for l in eff_base.layers])} / {len(eff_base.layers)}")

eff_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

eff_history_phase3 = eff_model.fit(
    eff_full_train_dataset,
    validation_data=eff_val_dataset,
    epochs=EFF_EPOCHS,
    class_weight=class_weight,
    callbacks=[reduce_lr, early_stop],
)

print("\n=== FINAL EfficientNetB2 EVALUATION ===")
eff_test_loss, eff_test_acc = eff_model.evaluate(eff_test_dataset, verbose=0)
print(f"EfficientNetB2 final test accuracy: {eff_test_acc:.4f}")
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 116s 873ms/step - accuracy: 0.4919 - loss: 1.2022 - val_accuracy: 0.5469 - val_loss: 0.9264
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 169ms/step - accuracy: 0.5067 - loss: 1.3605 - val_accuracy: 0.5684 - val_loss: 0.9028 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - accuracy: 0.5467 - loss: 1.1492 - val_accuracy: 0.5859 - val_loss: 0.8841 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - accuracy: 0.5499 - loss: 1.0915 - val_accuracy: 0.5811 - val_loss: 0.8671 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 164ms/step - accuracy: 0
50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.7647 - loss: 0.5599 - val_accuracy: 0.7676 - val_loss: 0.5311 - learning_rate: 1.0000e-04
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7901 - loss: 0.5421 - val_accuracy: 0.7764 - val_loss: 0.5057 - learning_rate: 1.0000e-04
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.7831 - loss: 0.5324 - val_accuracy: 0.8018 - val_loss: 0.4885 - learning_rate: 1.0000e-04
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8003 - loss: 0.5071 - val_accuracy: 0.8096 - val_loss: 0.4681 - learning_rate: 1.0000e-04
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.7952 - loss: 0.5108 - val_accuracy: 0.8096 - val_loss: 0.4674 - learning_rate: 1.0000e-04
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8062 - loss: 0.4779 - val_accuracy: 0.8115 - val_loss: 0.4520 - learning_rate: 1.0000e-04
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.8326 - loss: 0.4428 - val_accuracy: 0.7979 - val_loss: 0.4902 - learning_rate: 1.0000e-04
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8305 - loss: 0.4383 - val_accuracy: 0.8320 - val_loss: 0.4178 - learning_rate: 1.0000e-04
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.8450 - loss: 0.4040 - val_accuracy: 0.8320 - val_loss: 0.4133 - learning_rate: 1.0000e-04
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8471 - loss: 0.4184 - val_accuracy: 0.8350 - val_loss: 0.4202 - learning_rate: 1.0000e-04
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8502 - loss: 0.3997 - val_accuracy: 0.8564 - val_loss: 0.3854 - learning_rate: 1.0000e-04
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8540 - loss: 0.4018 - val_accuracy: 0.8359 - val_loss: 0.4039 - learning_rate: 1.0000e-04
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.8610 - loss: 0.3831 - val_accuracy: 0.8105 - val_loss: 0.4529 - learning_rate: 1.0000e-04
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.8656 - loss: 0.3666 - val_accuracy: 0.8545 - val_loss: 0.3719 - learning_rate: 1.0000e-04
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8666 - loss: 0.3575 - val_accuracy: 0.8262 - val_loss: 0.4325 - learning_rate: 1.0000e-04
# Epoch 26/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8705 - loss: 0.3371 - val_accuracy: 0.8584 - val_loss: 0.3411 - learning_rate: 1.0000e-04
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8758 - loss: 0.3274 - val_accuracy: 0.8623 - val_loss: 0.3623 - learning_rate: 1.0000e-04
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8759 - loss: 0.3282 - val_accuracy: 0.8838 - val_loss: 0.3346 - learning_rate: 1.0000e-04
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8803 - loss: 0.3224 - val_accuracy: 0.8721 - val_loss: 0.3402 - learning_rate: 1.0000e-04
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8886 - loss: 0.2979 - val_accuracy: 0.8848 - val_loss: 0.3067 - learning_rate: 1.0000e-04
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.8862 - loss: 0.3146 - val_accuracy: 0.8848 - val_loss: 0.3264 - learning_rate: 1.0000e-04
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8964 - loss: 0.2878 - val_accuracy: 0.8975 - val_loss: 0.3106 - learning_rate: 1.0000e-04
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9064 - loss: 0.2759 - val_accuracy: 0.8711 - val_loss: 0.3394 - learning_rate: 1.0000e-04
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.8964 - loss: 0.2844 - val_accuracy: 0.8652 - val_loss: 0.3499 - learning_rate: 1.0000e-04
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.8946 - loss: 0.2847 - val_accuracy: 0.8887 - val_loss: 0.3044 - learning_rate: 1.0000e-04
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9009 - loss: 0.2847 - val_accuracy: 0.9004 - val_loss: 0.2843 - learning_rate: 1.0000e-04
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9043 - loss: 0.2681 - val_accuracy: 0.8975 - val_loss: 0.2688 - learning_rate: 1.0000e-04
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9275 - loss: 0.2267 - val_accuracy: 0.8936 - val_loss: 0.2775 - learning_rate: 1.0000e-04
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9227 - loss: 0.2321 - val_accuracy: 0.8779 - val_loss: 0.3168 - learning_rate: 1.0000e-04
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9115 - loss: 0.2500 - val_accuracy: 0.8945 - val_loss: 0.2724 - learning_rate: 1.0000e-04
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9170 - loss: 0.2318 - val_accuracy: 0.9033 - val_loss: 0.2913 - learning_rate: 1.0000e-04
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9121 - loss: 0.2338 - val_accuracy: 0.9053 - val_loss: 0.2598 - learning_rate: 1.0000e-04
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9177 - loss: 0.2295 - val_accuracy: 0.8926 - val_loss: 0.2898 - learning_rate: 1.0000e-04
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9189 - loss: 0.2245 - val_accuracy: 0.8994 - val_loss: 0.2913 - learning_rate: 1.0000e-04
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9183 - loss: 0.2271 - val_accuracy: 0.9092 - val_loss: 0.2509 - learning_rate: 1.0000e-04
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9212 - loss: 0.2200 - val_accuracy: 0.8975 - val_loss: 0.2885 - learning_rate: 1.0000e-04
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9260 - loss: 0.2011 - val_accuracy: 0.9053 - val_loss: 0.2797 - learning_rate: 1.0000e-04
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9180 - loss: 0.2150 - val_accuracy: 0.9141 - val_loss: 0.2612 - learning_rate: 1.0000e-04
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9274 - loss: 0.1920 - val_accuracy: 0.9082 - val_loss: 0.2525 - learning_rate: 1.0000e-04
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.9382 - loss: 0.1847 - val_accuracy: 0.8838 - val_loss: 0.2880 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 48.
#
# === FINAL EfficientNetB2 EVALUATION ===
# EfficientNetB2 final test accuracy: 0.8977

# %%
save_dir = "/content/drive/MyDrive/alz_models"
os.makedirs(save_dir, exist_ok=True)

eff_path = os.path.join(save_dir, "SYNTHandCBAM_EFF.keras")
eff_model.save(eff_path)

print("Saved EFF model to:", eff_path)
# Out:
# Saved EFF model to: /content/drive/MyDrive/alz_models/SYNTHandCBAM_EFF.keras

# %%
y_true = []
y_pred = []

for images, labels in eff_test_dataset:
    preds = eff_model.predict(images)

    true_classes = np.argmax(labels.numpy(), axis=1)

    y_true.extend(true_classes)
    y_pred.extend(np.argmax(preds, axis=1))

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 22s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# [[123   0  15  34]
#  [  0  13   1   1]
#  [  4   0 598  32]
#  [  2   0  41 416]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82       172
#            1       1.00      0.87      0.93        15
#            2       0.91      0.94      0.93       634
#            3       0.86      0.91      0.88       459
#
#     accuracy                           0.90      1280
#    macro avg       0.93      0.86      0.89      1280
# weighted avg       0.90      0.90      0.90      1280

# %%
vgg_probs = vgg_model.predict(vgg_test_dataset)
eff_probs = eff_model.predict(eff_test_dataset)

ensemble_probs = (vgg_probs + eff_probs) / 2.0
ensemble_preds = np.argmax(ensemble_probs, axis=1)

onehot_labels = np.concatenate([y.numpy() for _, y in vgg_test_dataset], axis=0)
y_true = np.argmax(onehot_labels, axis=1)

vgg_preds = np.argmax(vgg_probs, axis=1)
eff_preds = np.argmax(eff_probs, axis=1)

print("VGG16 test accuracy: ", accuracy_score(y_true, vgg_preds))
print("EfficientNetB2 test acc: ", accuracy_score(y_true, eff_preds))
print("Ensemble test accuracy: ", accuracy_score(y_true, ensemble_preds))

print("\nEnsemble classification report:")
print(classification_report(y_true, ensemble_preds, digits=4))

print("\nEnsemble confusion matrix:")
print(confusion_matrix(y_true, ensemble_preds))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 488ms/step
# VGG16 test accuracy:  0.9609375
# EfficientNetB2 test acc:  0.89765625
# Ensemble test accuracy:  0.96875
#
# Ensemble classification report:
#               precision    recall  f1-score   support
#
#            0     0.9935    0.8953    0.9419       172
#            1     1.0000    0.8667    0.9286        15
#            2     0.9873    0.9795    0.9834       634
#            3     0.9358    0.9847    0.9597       459
#
#     accuracy                         0.9688      1280
#    macro avg     0.9792    0.9316    0.9534      1280
# weighted avg     0.9698    0.9688    0.9687      1280
#
#
# Ensemble confusion matrix:
# [[154   0   1  17]
#  [  0  13   0   2]
#  [  1   0 621  12]
#  [  0   0   7 452]]

# %%
# Paths must match where you saved them above
vgg_path = "/content/drive/MyDrive/alz_models/SYNTHandCBAM_VGG.keras"
eff_path = "/content/drive/MyDrive/alz_models/SYNTHandCBAM_EFF.keras"

# Load models
vggmodel = load_model(vgg_path, compile=False)
effmodel = load_model(eff_path, compile=False)

# Get probabilities on the test sets
vgg_probs = vggmodel.predict(vggtestdataset)
eff_probs = effmodel.predict(efftestdataset)

# Simple average ensemble
ensemble_probs = (vgg_probs + eff_probs) / 2.0
ensemble_preds = np.argmax(ensemble_probs, axis=1)

# True labels from the VGG test dataset (same as your current code)
onehot_labels = np.concatenate([y.numpy() for _, y in vggtestdataset], axis=0)
y_true = np.argmax(onehot_labels, axis=1)

# Individual model predictions
vgg_preds = np.argmax(vgg_probs, axis=1)
eff_preds = np.argmax(eff_probs, axis=1)

print("VGG16 test accuracy: ", accuracy_score(y_true, vgg_preds))
print("EfficientNetB2 test acc: ", accuracy_score(y_true, eff_preds))
print("Ensemble test accuracy: ", accuracy_score(y_true, ensemble_preds))

print("\nEnsemble classification report:")
print(classification_report(y_true, ensemble_preds, digits=4))

print("\nEnsemble confusion matrix:")
print(confusion_matrix(y_true, ensemble_preds))
