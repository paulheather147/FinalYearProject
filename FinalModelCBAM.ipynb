# %% [markdown]
# <a href="https://colab.research.google.com/github/paulheather147/FinalYearProject/blob/main/FinalModelCBAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Final Model with CBAM")
# Out:
# Final Model with CBAM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q datasets

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16, EfficientNetB2
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_preprocess
from datasets import load_dataset, Dataset

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import numpy as np

from PIL import Image
import os
import matplotlib.pyplot as plt
import cv2
import torch
import glob
import math

from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate, Conv2D, Add, Activation, Lambda
from tensorflow.keras import backend as K

# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA L4 (UUID: GPU-d33413cc-0772-0ff0-1c67-9874d404b88d)

# %%
dataset = load_dataset("Falah/Alzheimer_MRI")
print(dataset)
print(dataset["train"].features)

# %%
train_val_split = dataset["train"].train_test_split(test_size=0.2, seed=42)
train = train_val_split["train"]
val = train_val_split["test"]
test = dataset["test"]

def ensure_channel_dim(images):
    current_rank = tf.rank(images)

    def add_channel():
        return tf.expand_dims(images, axis=-1)

    def keep_same():
        return images

    return tf.cond(tf.equal(current_rank, 2), add_channel, keep_same)


def ensure_rgb_channels(images):
    current_channels = tf.shape(images)[-1]

    def to_rgb():
        return tf.image.grayscale_to_rgb(images)

    def drop_alpha():
        return images[..., :3]

    def keep_same():
        return images

    images = tf.cond(tf.equal(current_channels, 1), to_rgb, keep_same)

    new_channels = tf.shape(images)[-1]

    def keep_images_rgb():
        return images

    images = tf.cond(tf.equal(new_channels, 4), drop_alpha, keep_images_rgb)
    return images

def to_tensorflow_dataset(dataset_split, image_size, preprocess_fn, shuffle=False):
        dataset_tf = dataset_split.to_tf_dataset(
        columns=["image", "label"],
        shuffle=shuffle,
        num_workers=0,
    )
        def preprocess_input(example_dict):
            images = tf.cast(example_dict["image"], tf.float32)
            images = ensure_channel_dim(images)
            images = ensure_rgb_channels(images)
            images.set_shape([None, None, 3])
            images = tf.image.resize(images, (image_size, image_size))

            images = preprocess_fn(images)

            labels = tf.cast(example_dict["label"], tf.int32)
            labels = tf.one_hot(labels, depth=4)
            return images, labels

        dataset_tf = dataset_tf.map(preprocess_input,
                                    num_parallel_calls=tf.data.AUTOTUNE)
        dataset_tf = dataset_tf.batch(50)
        return dataset_tf.prefetch(tf.data.AUTOTUNE)

vgg_clean_train = to_tensorflow_dataset(train, 224, vgg_preprocess, shuffle=True)
eff_clean_train = to_tensorflow_dataset(train, 260, eff_preprocess, shuffle=True)

vgg_train_dataset = to_tensorflow_dataset(train, 224, vgg_preprocess, shuffle=True)
vgg_val_dataset = to_tensorflow_dataset(val, 224, vgg_preprocess, shuffle=False)
vgg_test_dataset = to_tensorflow_dataset(test, 224, vgg_preprocess, shuffle=False)

eff_train_dataset = to_tensorflow_dataset(train, 260, eff_preprocess, shuffle=True)
eff_val_dataset = to_tensorflow_dataset(val, 260, eff_preprocess, shuffle=False)
eff_test_dataset = to_tensorflow_dataset(test, 260, eff_preprocess, shuffle=False)

vgg_full_train_dataset = vgg_train_dataset
eff_full_train_dataset = eff_train_dataset

# %%
def channel_attention(x, ratio=8):
    ch = K.int_shape(x)[-1]
    hidden = max(ch // ratio, 1)

    shared_1 = layers.Dense(hidden, activation="relu", kernel_initializer="he_normal", use_bias=True)
    shared_2 = layers.Dense(ch, kernel_initializer="he_normal", use_bias=True)

    avg = layers.GlobalAveragePooling2D(keepdims=True)(x)
    mx  = layers.GlobalMaxPooling2D(keepdims=True)(x)

    attn = layers.Add()([shared_2(shared_1(avg)), shared_2(shared_1(mx))])
    attn = layers.Activation("sigmoid")(attn)
    return layers.Multiply()([x, attn])

def spatial_attention(x, kernel_size=7):
    avg = tf.keras.ops.mean(x, axis=-1, keepdims=True)
    mx  = tf.keras.ops.max(x, axis=-1, keepdims=True)
    concat = layers.Concatenate(axis=-1)([avg, mx])
    attn = layers.Conv2D(
        1, kernel_size, padding="same", activation="sigmoid",
        kernel_initializer="he_normal", use_bias=False
    )(concat)
    return layers.Multiply()([x, attn])

def cbam_block(x, ratio=8):
    y = channel_attention(x, ratio)
    y = spatial_attention(y)
    return layers.Add()([x, y])

# %%
vgg_base = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3),
)

vgg_base.trainable = False

vgg_inputs = tf.keras.Input(shape=(224, 224, 3))
x = vgg_base(vgg_inputs, training=False)
x = cbam_block(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
vgg_outputs = layers.Dense(4, activation="softmax")(x)

vgg_model = tf.keras.Model(vgg_inputs, vgg_outputs)

vgg_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

vgg_model.summary()

# use add_1 for gradcam
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1, 1, 512) │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 1, 1, 512) │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 64)  │     32,832 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 512) │     33,280 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 512) │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 1, 512) │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 7, 7, 512) │          0 │ vgg16[0][0],      │
# │                     │                   │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean (Mean)         │ (None, 7, 7, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max (Max)           │ (None, 7, 7, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 7, 7, 2)   │          0 │ mean[0][0],       │
# │ (Concatenate)       │                   │            │ max[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 7, 7, 1)   │         98 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 7, 7, 512) │          0 │ multiply[0][0],   │
# │ (Multiply)          │                   │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 7, 7, 512) │          0 │ vgg16[0][0],      │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ add_1[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      1,028 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,913,254 (56.89 MB)
#  Trainable params: 198,566 (775.65 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
VGG_EPOCHS = 50

class_weight = {
    0: 1.25,
    1: 2.0,
    2: 1.0,
    3: 1.0,
}

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=5,
    min_lr=1e-6
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

vgg_history_phase0 = vgg_model.fit(
    vgg_clean_train,
    validation_data=vgg_val_dataset,
    epochs=1,
    class_weight=class_weight,
)

vgg_history_phase2 = vgg_model.fit(
    vgg_full_train_dataset,
    validation_data = vgg_val_dataset,
    epochs = VGG_EPOCHS,
    class_weight = class_weight,
    callbacks = [reduce_lr, early_stop]
)

print("\n=== PHASE 2: Fine-tuning top layers ===")
vgg_base.trainable = True
for layer in vgg_base.layers[:-8]:
    layer.trainable = False

print(f"Trainable layers: {sum([l.trainable for l in vgg_base.layers])} / {len(vgg_base.layers)}")

vgg_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

vgg_history_phase3 = vgg_model.fit(
    vgg_full_train_dataset,
    validation_data = vgg_val_dataset,
    epochs = VGG_EPOCHS,
    class_weight = class_weight,
    callbacks = [reduce_lr, early_stop]
)

print("\n=== FINAL VGG16 EVALUATION ===")
vgg_test_loss, vgg_test_acc = vgg_model.evaluate(vgg_test_dataset, verbose=0)
print(f"VGG16 final test accuracy: {vgg_test_acc:.4f}")
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 68s 532ms/step - accuracy: 0.4221 - loss: 2.8623 - val_accuracy: 0.5879 - val_loss: 0.9613
# Epoch 1/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.5458 - loss: 1.0249 - val_accuracy: 0.5869 - val_loss: 0.8917 - learning_rate: 0.0010
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 16s 200ms/step - accuracy: 0.5787 - loss: 0.9799 - val_accuracy: 0.6201 - val_loss: 0.8673 - learning_rate: 0.0010
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.6014 - loss: 0.9242 - val_accuracy: 0.6201 - val_loss: 0.8343 - learning_rate: 0.0010
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.6059 - loss: 0.8998 - val_accuracy: 0.6279 - val_loss: 0.8053 - learning_rate: 0.0010
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.6279 - loss: 0.8332 - val_accuracy: 0.6230 - val_loss: 0.8162 - learning_rate: 0.0010
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.6530 - loss: 0.8302 - val_accuracy: 0.6553 - val_loss: 0.7788 - learning_rate: 0.0010
# Epoch 7/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.6650 - loss: 0.7905 - val_accuracy: 0.6533 - val_loss: 0.7670 - learning_rate: 0.0010
# Epoch 8/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.6695 - loss: 0.7629 - val_accuracy: 0.6904 - val_loss: 0.7149 - learning_rate: 0.0010
# Epoch 9/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.6849 - loss: 0.7456 - val_accuracy: 0.6611 - val_loss: 0.7310 - learning_rate: 0.0010
# Epoch 10/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.6900 - loss: 0.7270 - val_accuracy: 0.7002 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.7103 - loss: 0.6879 - val_accuracy: 0.6943 - val_loss: 0.6896 - learning_rate: 0.0010
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.7042 - loss: 0.6862 - val_accuracy: 0.6992 - val_loss: 0.6519 - learning_rate: 0.0010
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0.7226 - loss: 0.6618 - val_accuracy: 0.7041 - val_loss: 0.6746 - learning_rate: 0.0010
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7271 - loss: 0.6423 - val_accuracy: 0.7217 - val_loss: 0.6239 - learning_rate: 0.0010
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7420 - loss: 0.6242 - val_accuracy: 0.7285 - val_loss: 0.6267 - learning_rate: 0.0010
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7536 - loss: 0.5818 - val_accuracy: 0.7061 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7573 - loss: 0.5757 - val_accuracy: 0.7363 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7673 - loss: 0.5561 - val_accuracy: 0.7217 - val_loss: 0.6548 - learning_rate: 0.0010
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7688 - loss: 0.5900 - val_accuracy: 0.7412 - val_loss: 0.6059 - learning_rate: 0.0010
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7790 - loss: 0.5359 - val_accuracy: 0.7578 - val_loss: 0.5781 - learning_rate: 0.0010
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7686 - loss: 0.5482 - val_accuracy: 0.7549 - val_loss: 0.5721 - learning_rate: 0.0010
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7682 - loss: 0.5479 - val_accuracy: 0.7539 - val_loss: 0.5664 - learning_rate: 0.0010
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.7711 - loss: 0.5181 - val_accuracy: 0.7695 - val_loss: 0.5380 - learning_rate: 0.0010
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 17s 202ms/step - accuracy: 0
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 0.9942 - loss: 0.0181 - val_accuracy: 0.9287 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 0.9933 - loss: 0.0225 - val_accuracy: 0.9365 - val_loss: 0.2650 - learning_rate: 1.0000e-04
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 0.9954 - loss: 0.0149 - val_accuracy: 0.8926 - val_loss: 0.3541 - learning_rate: 1.0000e-04
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 0.9915 - loss: 0.0374 - val_accuracy: 0.9375 - val_loss: 0.2590 - learning_rate: 1.0000e-05
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9385 - val_loss: 0.2620 - learning_rate: 1.0000e-05
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9404 - val_loss: 0.2689 - learning_rate: 1.0000e-05
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9414 - val_loss: 0.2733 - learning_rate: 1.0000e-05
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9414 - val_loss: 0.2782 - learning_rate: 1.0000e-05
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9434 - val_loss: 0.2846 - learning_rate: 1.0000e-05
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9434 - val_loss: 0.2864 - learning_rate: 1.0000e-05
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 268ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9453 - val_loss: 0.2889 - learning_rate: 1.0000e-05
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 8.7967e-04 - val_accuracy: 0.9453 - val_loss: 0.2924 - learning_rate: 1.0000e-05
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 8.1310e-04 - val_accuracy: 0.9443 - val_loss: 0.2964 - learning_rate: 1.0000e-05
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9434 - val_loss: 0.2980 - learning_rate: 1.0000e-05
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 5.0989e-04 - val_accuracy: 0.9434 - val_loss: 0.3018 - learning_rate: 1.0000e-05
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 5.6619e-04 - val_accuracy: 0.9443 - val_loss: 0.3074 - learning_rate: 1.0000e-05
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 4.7267e-04 - val_accuracy: 0.9434 - val_loss: 0.3074 - learning_rate: 1.0000e-06
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 7.6801e-04 - val_accuracy: 0.9443 - val_loss: 0.3074 - learning_rate: 1.0000e-06
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 5.0077e-04 - val_accuracy: 0.9443 - val_loss: 0.3077 - learning_rate: 1.0000e-06
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 4.4907e-04 - val_accuracy: 0.9443 - val_loss: 0.3080 - learning_rate: 1.0000e-06
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 5.0899e-04 - val_accuracy: 0.9443 - val_loss: 0.3080 - learning_rate: 1.0000e-06
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 1.0000 - loss: 5.0481e-04 - val_accuracy: 0.9443 - val_loss: 0.3085 - learning_rate: 1.0000e-06
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 266ms/step - accuracy: 1.0000 - loss: 4.5072e-04 - val_accuracy: 0.9443 - val_loss: 0.3085 - learning_rate: 1.0000e-06
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 37.
#
# === FINAL VGG16 EVALUATION ===
# VGG16 final test accuracy: 0.9555

# %%
save_dir = "/content/drive/MyDrive/alz_models"
os.makedirs(save_dir, exist_ok=True)

vgg_path = os.path.join(save_dir, "CBAM_VGG.keras")
vgg_model.save(vgg_path)

print("Saved VGG model to:", vgg_path)
# Out:
# Saved VGG model to: /content/drive/MyDrive/alz_models/CBAM_VGG.keras

# %%
y_true = []
y_pred = []

for images, labels in vgg_test_dataset:
    preds = vgg_model.predict(images)

    true_classes = np.argmax(labels.numpy(), axis=1)

    y_true.extend(true_classes)
    y_pred.extend(np.argmax(preds, axis=1))

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3434994215.py in <cell line: 0>()
#       2 y_pred = []
#       3
# ----> 4 for images, labels in vgg_test_dataset:
#       5     preds = vgg_model.predict(images)
#       6
#
# NameError: name 'vgg_test_dataset' is not defined

# %%
eff_base = EfficientNetB2(
    weights="imagenet",
    include_top=False,
    input_shape=(260, 260, 3),
)
eff_base.trainable = False

eff_inputs = tf.keras.Input(shape=(260, 260, 3))
y = eff_base(eff_inputs, training=False)
y = layers.GlobalAveragePooling2D()(y)
y = layers.Dense(256, activation="relu")(y)
y = layers.Dropout(0.5)(y)
eff_outputs = layers.Dense(4, activation="softmax")(y)

eff_model = tf.keras.Model(eff_inputs, eff_outputs)

eff_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

eff_model.summary()

# use top_conv for gradcam
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 260, 260, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb2 (Functional)     │ (None, 9, 9, 1408)     │     7,768,569 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1408)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       360,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,130,301 (31.01 MB)
#  Trainable params: 361,732 (1.38 MB)
#  Non-trainable params: 7,768,569 (29.63 MB)

# %%
EFF_EPOCHS = 50

class_weight = {
    0: 1.25,
    1: 2.0,
    2: 1.0,
    3: 1.0,
}

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=5,
    min_lr=1e-6
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True,
    verbose=1
)

eff_history_phase0 = eff_model.fit(
    eff_clean_train,
    validation_data=eff_val_dataset,
    epochs=1,
    class_weight=class_weight,
)

eff_history_phase2 = eff_model.fit(
    eff_full_train_dataset,
    validation_data=eff_val_dataset,
    epochs=EFF_EPOCHS,
    class_weight=class_weight,
    callbacks = [reduce_lr, early_stop]
)

print("\n=== PHASE 2: Fine-tuning top layers ===")
eff_base.trainable = True
for layer in eff_base.layers[:-8]:
    layer.trainable = False

print(f"Trainable layers: {sum([l.trainable for l in eff_base.layers])} / {len(eff_base.layers)}")

eff_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

eff_history_phase3 = eff_model.fit(
    eff_full_train_dataset,
    validation_data=eff_val_dataset,
    epochs=EFF_EPOCHS,
    class_weight=class_weight,
    callbacks=[reduce_lr, early_stop],
)

print("\n=== FINAL EfficientNetB2 EVALUATION ===")
eff_test_loss, eff_test_acc = eff_model.evaluate(eff_test_dataset, verbose=0)
print(f"EfficientNetB2 final test accuracy: {eff_test_acc:.4f}")
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 128s 943ms/step - accuracy: 0.4774 - loss: 1.1684 - val_accuracy: 0.5654 - val_loss: 0.9343
# Epoch 1/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.5527 - loss: 1.0216 - val_accuracy: 0.5361 - val_loss: 0.9418 - learning_rate: 0.0010
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.5489 - loss: 1.0175 - val_accuracy: 0.5771 - val_loss: 0.8764 - learning_rate: 0.0010
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.5642 - loss: 0.9564 - val_accuracy: 0.5830 - val_loss: 0.8725 - learning_rate: 0.0010
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 169ms/step - accuracy: 0.5688 - loss: 0.9664 - val_accuracy: 0.5752 - val_loss: 0.8519 - learning_rate: 0.0010
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.5631 - loss: 0.9340 - val_accuracy: 0.5762 - val_loss: 0.8579 - learning_rate: 0.0010
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.5836 - loss: 0.9434 - val_accuracy: 0.5947 - val_loss: 0.8332 - learning_rate: 0.0010
# Epoch 7/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.6961 - loss: 0.7057 - val_accuracy: 0.7158 - val_loss: 0.6403 - learning_rate: 1.0000e-04
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.6852 - loss: 0.7196 - val_accuracy: 0.7178 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7056 - loss: 0.7089 - val_accuracy: 0.7119 - val_loss: 0.6442 - learning_rate: 1.0000e-04
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.7004 - loss: 0.7089 - val_accuracy: 0.7236 - val_loss: 0.6365 - learning_rate: 1.0000e-04
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7116 - loss: 0.6947 - val_accuracy: 0.7168 - val_loss: 0.6366 - learning_rate: 1.0000e-04
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.6833 - loss: 0.7127 - val_accuracy: 0.7139 - val_loss: 0.6368 - learning_rate: 1.0000e-04
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.6935 - loss: 0.7042 - val_accuracy: 0.7188 - val_loss: 0.6325 - learning_rate: 1.0000e-04
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.7022 - loss: 0.6973 - val_accuracy: 0.7285 - val_loss: 0.6305 - learning_rate: 1.0000e-04
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.6984 - loss: 0.7149 - val_accuracy: 0.7168 - val_loss: 0.6327 - learning_rate: 1.0000e-04
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7037 - loss: 0.6992 - val_accuracy: 0.7168 - val_loss: 0.6311 - learning_rate: 1.0000e-04
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.7043 - loss: 0.6986 - val_accuracy: 0.7275 - val_loss: 0.6285 - learning_rate: 1.0000e-04
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.6964 - loss: 0.7160 - val_accuracy: 0.7266 - val_loss: 0.6332 - learning_rate: 1.0000e-04
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.7053 - loss: 0.7219 - val_accuracy: 0.7158 - val_loss: 0.6345 - learning_rate: 1.0000e-04
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.7018 - loss: 0.6962 - val_accuracy: 0.7178 - val_loss: 0.6325 - learning_rate: 1.0000e-05
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.7154 - loss: 0.6945 - val_accuracy: 0.7207 - val_loss: 0.6304 - learning_rate: 1.0000e-05
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.7285 - loss: 0.6765 - val_accuracy: 0.7246 - val_loss: 0.6289 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 42.
#
# === PHASE 2: Fine-tuning top layers ===
# Trainable layers: 8 / 340
# Epoch 1/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 86s 607ms/step - accuracy: 0.6754 - loss: 0.7946 - val_accuracy: 0.7207 - val_loss: 0.6298 - learning_rate: 1.0000e-04
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.6963 - loss: 0.7183 - val_accuracy: 0.7285 - val_loss: 0.6108 - learning_rate: 1.0000e-04
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 15s 176ms/step - accuracy: 0.7182 - loss: 0.6778 - val_accuracy: 0.7383 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.7335 - loss: 0.6445 - val_accuracy: 0.7568 - val_loss: 0.5735 - learning_rate: 1.0000e-04
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.7434 - loss: 0.6302 - val_accuracy: 0.7695 - val_loss: 0.5608 - learning_rate: 1.0000e-04
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.7578 - loss: 0.6053 - val_accuracy: 0.7598 - val_loss: 0.5511 - learning_rate: 1.0000e-04
# Epoch 7/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.7552 - loss: 0.5798 - val_accuracy: 0.7910 - val_loss: 0.5230 - learning_rate: 1.0000e-04
# Epoch 8/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.7660 - loss: 0.5806 - val_accuracy: 0.7666 - val_loss: 0.5388 - learning_rate: 1.0000e-04
# Epoch 9/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.7948 - loss: 0.5413 - val_accuracy: 0.7598 - val_loss: 0.5433 - learning_rate: 1.0000e-04
# Epoch 10/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.7906 - loss: 0.5360 - val_accuracy: 0.7725 - val_loss: 0.5174 - learning_rate: 1.0000e-04
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.7938 - loss: 0.5051 - val_accuracy: 0.7979 - val_loss: 0.4710 - learning_rate: 1.0000e-04
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.7989 - loss: 0.5059 - val_accuracy: 0.8232 - val_loss: 0.4602 - learning_rate: 1.0000e-04
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.8044 - loss: 0.4819 - val_accuracy: 0.8252 - val_loss: 0.4473 - learning_rate: 1.0000e-04
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8159 - loss: 0.4568 - val_accuracy: 0.8193 - val_loss: 0.4477 - learning_rate: 1.0000e-04
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.8119 - loss: 0.4583 - val_accuracy: 0.8389 - val_loss: 0.4259 - learning_rate: 1.0000e-04
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8249 - loss: 0.4487 - val_accuracy: 0.8086 - val_loss: 0.4657 - learning_rate: 1.0000e-04
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8264 - loss: 0.4416 - val_accuracy: 0.8203 - val_loss: 0.4742 - learning_rate: 1.0000e-04
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.8306 - loss: 0.4347 - val_accuracy: 0.8408 - val_loss: 0.4237 - learning_rate: 1.0000e-04
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8449 - loss: 0.3973 - val_accuracy: 0.8379 - val_loss: 0.3968 - learning_rate: 1.0000e-04
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.8406 - loss: 0.4059 - val_accuracy: 0.8545 - val_loss: 0.3870 - learning_rate: 1.0000e-04
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.8510 - loss: 0.3801 - val_accuracy: 0.7656 - val_loss: 0.5028 - learning_rate: 1.0000e-04
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8478 - loss: 0.3868 - val_accuracy: 0.8545 - val_loss: 0.3632 - learning_rate: 1.0000e-04
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.8566 - loss: 0.3809 - val_accuracy: 0.8682 - val_loss: 0.3559 - learning_rate: 1.0000e-04
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8714 - loss: 0.3524 - val_accuracy: 0.8135 - val_loss: 0.4642 - learning_rate: 1.0000e-04
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.8589 - loss: 0.3806 - val_accuracy: 0.8750 - val_loss: 0.3328 - learning_rate: 1.0000e-04
# Epoch 26/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8721 - loss: 0.3552 - val_accuracy: 0.8662 - val_loss: 0.3582 - learning_rate: 1.0000e-04
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.8862 - loss: 0.3163 - val_accuracy: 0.8857 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8836 - loss: 0.3216 - val_accuracy: 0.8711 - val_loss: 0.3432 - learning_rate: 1.0000e-04
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8744 - loss: 0.3186 - val_accuracy: 0.8779 - val_loss: 0.3137 - learning_rate: 1.0000e-04
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.8962 - loss: 0.3035 - val_accuracy: 0.8809 - val_loss: 0.3141 - learning_rate: 1.0000e-04
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.8997 - loss: 0.2903 - val_accuracy: 0.8945 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.8972 - loss: 0.2912 - val_accuracy: 0.8887 - val_loss: 0.3173 - learning_rate: 1.0000e-04
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9038 - loss: 0.2626 - val_accuracy: 0.8594 - val_loss: 0.3535 - learning_rate: 1.0000e-04
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9013 - loss: 0.2684 - val_accuracy: 0.8838 - val_loss: 0.3148 - learning_rate: 1.0000e-04
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.8955 - loss: 0.2823 - val_accuracy: 0.8975 - val_loss: 0.2949 - learning_rate: 1.0000e-04
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9042 - loss: 0.2576 - val_accuracy: 0.9004 - val_loss: 0.2772 - learning_rate: 1.0000e-04
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.9092 - loss: 0.2508 - val_accuracy: 0.8945 - val_loss: 0.2783 - learning_rate: 1.0000e-04
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9022 - loss: 0.2604 - val_accuracy: 0.8770 - val_loss: 0.3090 - learning_rate: 1.0000e-04
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9178 - loss: 0.2426 - val_accuracy: 0.8750 - val_loss: 0.3216 - learning_rate: 1.0000e-04
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9128 - loss: 0.2457 - val_accuracy: 0.8545 - val_loss: 0.3690 - learning_rate: 1.0000e-04
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9206 - loss: 0.2320 - val_accuracy: 0.8994 - val_loss: 0.2825 - learning_rate: 1.0000e-04
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9191 - loss: 0.2218 - val_accuracy: 0.9209 - val_loss: 0.2468 - learning_rate: 1.0000e-05
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9241 - loss: 0.2128 - val_accuracy: 0.9180 - val_loss: 0.2387 - learning_rate: 1.0000e-05
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9337 - loss: 0.1964 - val_accuracy: 0.9229 - val_loss: 0.2336 - learning_rate: 1.0000e-05
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9266 - loss: 0.2077 - val_accuracy: 0.9150 - val_loss: 0.2379 - learning_rate: 1.0000e-05
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9277 - loss: 0.2000 - val_accuracy: 0.9199 - val_loss: 0.2390 - learning_rate: 1.0000e-05
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9312 - loss: 0.1957 - val_accuracy: 0.9180 - val_loss: 0.2371 - learning_rate: 1.0000e-05
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9350 - loss: 0.1894 - val_accuracy: 0.9180 - val_loss: 0.2386 - learning_rate: 1.0000e-05
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9263 - loss: 0.1997 - val_accuracy: 0.9160 - val_loss: 0.2410 - learning_rate: 1.0000e-05
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9399 - loss: 0.1884 - val_accuracy: 0.9199 - val_loss: 0.2380 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 44.
#
# === FINAL EfficientNetB2 EVALUATION ===
# EfficientNetB2 final test accuracy: 0.8875

# %%
save_dir = "/content/drive/MyDrive/alz_models"
os.makedirs(save_dir, exist_ok=True)

eff_path = os.path.join(save_dir, "CBAM_EFF.keras")
eff_model.save(eff_path)

print("Saved EFF model to:", eff_path)
# Out:
# Saved EFF model to: /content/drive/MyDrive/alz_models/CBAM_EFF.keras

# %%
y_true = []
y_pred = []

for images, labels in eff_test_dataset:
    preds = eff_model.predict(images)

    true_classes = np.argmax(labels.numpy(), axis=1)

    y_true.extend(true_classes)
    y_pred.extend(np.argmax(preds, axis=1))

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))

# %%
vgg_probs = vgg_model.predict(vgg_test_dataset)
eff_probs = eff_model.predict(eff_test_dataset)

ensemble_probs = (vgg_probs + eff_probs) / 2.0
ensemble_preds = np.argmax(ensemble_probs, axis=1)

onehot_labels = np.concatenate([y.numpy() for _, y in vgg_test_dataset], axis=0)
y_true = np.argmax(onehot_labels, axis=1)

vgg_preds = np.argmax(vgg_probs, axis=1)
eff_preds = np.argmax(eff_probs, axis=1)

print("VGG16 test accuracy: ", accuracy_score(y_true, vgg_preds))
print("EfficientNetB2 test acc: ", accuracy_score(y_true, eff_preds))
print("Ensemble test accuracy: ", accuracy_score(y_true, ensemble_preds))

print("\nEnsemble classification report:")
print(classification_report(y_true, ensemble_preds, digits=4))

print("\nEnsemble confusion matrix:")
print(confusion_matrix(y_true, ensemble_preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1464157916.py in <cell line: 0>()
# ----> 1 vgg_probs = vgg_model.predict(vgg_test_dataset)
#       2 eff_probs = eff_model.predict(eff_test_dataset)
#       3
#       4 ensemble_probs = (vgg_probs + eff_probs) / 2.0
#       5 ensemble_preds = np.argmax(ensemble_probs, axis=1)
#
# NameError: name 'vgg_model' is not defined

# %%
from tensorflow.keras.models import load_model

vgg_path = "/content/drive/MyDrive/alz_models/CBAM_VGG.keras"
eff_path = "/content/drive/MyDrive/alz_models/CBAM_EFF.keras"

vggmodel = load_model(vgg_path, compile=False)
effmodel = load_model(eff_path, compile=False)

vgg_probs = vggmodel.predict(vgg_test_dataset)
eff_probs = effmodel.predict(eff_test_dataset)

ensemble_probs = (vgg_probs + eff_probs) / 2.0
ensemble_preds = np.argmax(ensemble_probs, axis=1)

onehot_labels = np.concatenate([y.numpy() for _, y in vgg_test_dataset], axis=0)
y_true = np.argmax(onehot_labels, axis=1)

vgg_preds = np.argmax(vgg_probs, axis=1)
eff_preds = np.argmax(eff_probs, axis=1)

print("VGG16 test accuracy: ", accuracy_score(y_true, vgg_preds))
print("EfficientNetB2 test acc: ", accuracy_score(y_true, eff_preds))
print("Ensemble test accuracy: ", accuracy_score(y_true, ensemble_preds))

print("\nEnsemble classification report:")
print(classification_report(y_true, ensemble_preds, digits=4))

print("\nEnsemble confusion matrix:")
print(confusion_matrix(y_true, ensemble_preds))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 28s 525ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 23s 505ms/step
# VGG16 test accuracy:  0.95546875
# EfficientNetB2 test acc:  0.8875
# Ensemble test accuracy:  0.96328125
#
# Ensemble classification report:
#               precision    recall  f1-score   support
#
#            0     0.9870    0.8837    0.9325       172
#            1     1.0000    0.9333    0.9655        15
#            2     0.9749    0.9811    0.9780       634
#            3     0.9388    0.9695    0.9539       459
#
#     accuracy                         0.9633      1280
#    macro avg     0.9752    0.9419    0.9575      1280
# weighted avg     0.9639    0.9633    0.9631      1280
#
#
# Ensemble confusion matrix:
# [[152   0   2  18]
#  [  0  14   0   1]
#  [  2   0 622  10]
#  [  0   0  14 445]]
